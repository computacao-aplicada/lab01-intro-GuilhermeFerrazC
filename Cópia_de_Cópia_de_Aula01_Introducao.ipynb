# %% [markdown]
# <a href="https://colab.research.google.com/github/computacao-aplicada/lab01-intro-GuilhermeFerrazC/blob/main/C%C3%B3pia_de_C%C3%B3pia_de_Aula01_Introducao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 01: Introdução à Visão Computacional e Computação Gráfica
#
# ### 🎯 Objetivos da Aula
# - Compreender o que é Visão Computacional.
# - Diferenciar Visão Computacional, Processamento de Imagens e Computação Gráfica.
# - Realizar manipulações simples com imagens.
# - Explorar conceitos de pixels, resoluções e canais de cor.

# %% [markdown]
# ## O que é Visão Computacional?
#
# A **Visão Computacional** é uma área da Inteligência Artificial que busca permitir que os computadores 'vejam' e interpretem o mundo visual, assim como os humanos.
#
# Ela utiliza imagens e vídeos como entrada e tenta extrair informações úteis, como:
# - Detecção de objetos
# - Reconhecimento facial
# - Segmentação de imagem
# - Rastreamento de movimento
#
# A **Computação Gráfica**, por outro lado, está mais voltada à geração de imagens — como renderizar cenas em 3D.
#
# Já o **Processamento de Imagens** se concentra na transformação e análise de imagens (normalmente 2D) para melhorar a qualidade ou extrair características.
#
# | Área                  | Foco                             |
# |-----------------------|----------------------------------|
# | Visão Computacional   | Entendimento e interpretação     |
# | Computação Gráfica    | Geração de imagens               |
# | Processamento de Imagens | Manipulação e melhoria de imagens |

# %% [markdown]
# ## Exemplo prático: Carregar e visualizar uma imagem

# %%
# Importar bibliotecas
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import requests

# Carregar imagem
url = "https://images.unsplash.com/photo-1745810187217-4d9e1ccfd9d5?ixlib=rb-4.1.0&q=85&fm=jpg&crop=entropy&cs=srgb&w=640"
image = Image.open(requests.get(url, stream=True).raw).convert("RGB")

# Mostrar imagem original
plt.imshow(image)
plt.title("Imagem Original")
plt.axis('off')
plt.show()

# %% [markdown]
# ## Manipulação dos canais RGB

# %%
# Separar canais RGB
r, g, b = image.split()

# Criar imagem apenas com o canal vermelho
red_channel = Image.merge("RGB", (r, Image.new("L", image.size), Image.new("L", image.size)))

# Exibir
plt.imshow(red_channel)
plt.title("Apenas Canal Vermelho")
plt.axis('off')
plt.show()

# %%
# Converter para array numpy
np_image = np.array(image)

# Modificar canal vermelho (R) com valores aleatórios
np_image[:, :, 0] = np.random.randint(0, 256, (np_image.shape[0], np_image.shape[1]), dtype=np.uint8)

# Converter de volta para imagem
modified_image = Image.fromarray(np_image)

# Exibir
plt.imshow(modified_image)
plt.title("Canal Vermelho Modificado")
plt.axis('off')
plt.show()

# %%
# Inverter cores (255 - valor do pixel)
negative_image = Image.fromarray(255 - np.array(image))

# Exibir
plt.imshow(negative_image)
plt.title("Imagem Negativa")
plt.axis('off')
plt.show()

# %%
negative_image.save("imagem_negativa.jpg")
print("imagem_negativa.jpg")
# Out:
# ✅ Imagem negativa salva como 'imagem_negativa.jpg'

# %%
# Coordenadas (left, top, right, bottom)
crop_coords = (150, 100, 450, 400)  # Ajuste conforme o tamanho da sua imagem

# Recortar
cropped_image = image.crop(crop_coords)

# Exibir
plt.imshow(cropped_image)
plt.title("Recorte da Imagem Original")
plt.axis('off')
plt.show()

# Salvar
cropped_image.save("recorte_original.jpg")
print("recorte_original.jpg")
# Out:
# ✅ Recorte original salvo como 'recorte_original.jpg'

# %%
# Usar a imagem negativa criada anteriormente
cropped_negative = negative_image.crop(crop_coords)  # Mesmas coordenadas

# Exibir
plt.imshow(cropped_negative)
plt.title("Recorte da Imagem Negativa")
plt.axis('off')
plt.show()

# Salvar
cropped_negative.save("recorte_negativo.jpg")
print("recorte_negativo.jpg")
# Out:
# ✅ Recorte negativo salvo como 'recorte_negativo.jpg'

# %% [markdown]
# ## 🧠 Exercício
#
# Tente modificar o código acima para:
#
# - Exibir apenas o canal vermelho da imagem.
# - Modifique aleatoriamente o canal vermelho e gere a imagem novamente.
# - Criar uma imagem negativa (inverter as cores).
# - Salvar uma nova imagem modificada no disco.
# - Recorte um pedaço da imagem e salve em disco.
#
# ---
# Cada um dos pontos do exercício deve ser uma célula separada!
